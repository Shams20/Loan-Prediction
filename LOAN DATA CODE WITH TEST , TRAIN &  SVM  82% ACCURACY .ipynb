# %% [markdown]
# LOAN DATA CODE

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
data =pd.read_csv('Train.csv')
df = pd.read_csv('Test.csv')

# %%
lc=data
lc
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
from sklearn import linear_model , metrics
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
lc.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
lc.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
lc.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
lc.corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %%
lc.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
## replacing from median value###
lc.LoanAmount.replace('',128.0)
# Out:
# 0        NaN
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %%
lc.LoanAmount.replace(np.nan,128.0,inplace=True)

# %%
lc
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
## treating gender through mode###
lc['Gender'].fillna(lc['Gender'].mode()[0],inplace=True)
lc
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lc.Gender.mode()
# Out:
# 0    Male
# dtype: object

# %%
lc['Married'].fillna(lc['Married'].mode()[0],inplace=True)
lc
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lc['Dependents'].fillna(lc['Dependents'].mode()[0],inplace=True)
lc
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lc['Education'].fillna(lc['Education'].mode()[0],inplace=True)
lc
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lc['Self_Employed'].fillna(lc['Self_Employed'].mode()[0],inplace=True)
lc
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lc.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
lc['Loan_Amount_Term'].fillna(lc['Loan_Amount_Term'].mode()[0],inplace=True)
lc
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lc['Credit_History'].fillna(lc['Credit_History'].mode()[0],inplace=True)
lc
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lc.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
lc.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
### making dummy value of gender as is object converting to integer
lc.Gender = pd.get_dummies(lc['Gender'], drop_first = True)
lc
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002       1      No          0      Graduate            No
# 1    LP001003       1     Yes          1      Graduate            No
# 2    LP001005       1     Yes          0      Graduate           Yes
# 3    LP001006       1     Yes          0  Not Graduate            No
# 4    LP001008       1      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978       0      No          0      Graduate            No
# 610  LP002979       1     Yes         3+      Graduate            No
# 611  LP002983       1     Yes          1      Graduate            No
# 612  LP002984       1     Yes          2      Graduate            No
# 613  LP002990       0      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lc.Married = pd.get_dummies(lc['Married'], drop_first = True)
lc
# Out:
#       Loan_ID  Gender  Married Dependents     Education Self_Employed  \
# 0    LP001002       1        0          0      Graduate            No
# 1    LP001003       1        1          1      Graduate            No
# 2    LP001005       1        1          0      Graduate           Yes
# 3    LP001006       1        1          0  Not Graduate            No
# 4    LP001008       1        0          0      Graduate            No
# ..        ...     ...      ...        ...           ...           ...
# 609  LP002978       0        0          0      Graduate            No
# 610  LP002979       1        1         3+      Graduate            No
# 611  LP002983       1        1          1      Graduate            No
# 612  LP002984       1        1          2      Graduate            No
# 613  LP002990       0        0          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lc.Dependents = pd.get_dummies(lc['Dependents'], drop_first = True)
lc
# Out:
#       Loan_ID  Gender  Married  Dependents     Education Self_Employed  \
# 0    LP001002       1        0           0      Graduate            No
# 1    LP001003       1        1           1      Graduate            No
# 2    LP001005       1        1           0      Graduate           Yes
# 3    LP001006       1        1           0  Not Graduate            No
# 4    LP001008       1        0           0      Graduate            No
# ..        ...     ...      ...         ...           ...           ...
# 609  LP002978       0        0           0      Graduate            No
# 610  LP002979       1        1           0      Graduate            No
# 611  LP002983       1        1           1      Graduate            No
# 612  LP002984       1        1           0      Graduate            No
# 613  LP002990       0        0           0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lc.Education = pd.get_dummies(lc['Education'], drop_first = True)
lc
# Out:
#       Loan_ID  Gender  Married  Dependents  Education Self_Employed  \
# 0    LP001002       1        0           0          0            No
# 1    LP001003       1        1           1          0            No
# 2    LP001005       1        1           0          0           Yes
# 3    LP001006       1        1           0          1            No
# 4    LP001008       1        0           0          0            No
# ..        ...     ...      ...         ...        ...           ...
# 609  LP002978       0        0           0          0            No
# 610  LP002979       1        1           0          0            No
# 611  LP002983       1        1           1          0            No
# 612  LP002984       1        1           0          0            No
# 613  LP002990       0        0           0          0           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# ...

# %%
lc.Self_Employed = pd.get_dummies(lc['Self_Employed'], drop_first = True)
lc
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          0              0
# 1    LP001003       1        1           1          0              0
# 2    LP001005       1        1           0          0              1
# 3    LP001006       1        1           0          1              0
# 4    LP001008       1        0           0          0              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          0              0
# 610  LP002979       1        1           0          0              0
# 611  LP002983       1        1           1          0              0
# 612  LP002984       1        1           0          0              0
# 613  LP002990       0        0           0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lc.Property_Area = pd.get_dummies(lc['Property_Area'], drop_first = True)
lc
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          0              0
# 1    LP001003       1        1           1          0              0
# 2    LP001005       1        1           0          0              1
# 3    LP001006       1        1           0          1              0
# 4    LP001008       1        0           0          0              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          0              0
# 610  LP002979       1        1           0          0              0
# 611  LP002983       1        1           1          0              0
# 612  LP002984       1        1           0          0              0
# 613  LP002990       0        0           0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
lc.dtypes
# Out:
# Loan_ID               object
# Gender                 uint8
# Married                uint8
# Dependents             uint8
# Education              uint8
# Self_Employed          uint8
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          uint8
# Loan_Status           object
# dtype: object

# %%
lc.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       1        0           0          0              0
# 1  LP001003       1        1           1          0              0
# 2  LP001005       1        1           0          0              1
# 3  LP001006       1        1           0          1              0
# 4  LP001008       1        0           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area Loan_Status
# 0             1.0              0           Y
# 1             1.0              0           N
# ...

# %%
## X is predicted value and Y is targeted value###
X = lc.drop(['Loan_Status', 'Loan_ID','Education'], axis = 1)
y = lc['Loan_Status']

# %%
# splitting X and y into training and testing sets 
    
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state = 41)

# %%
print(len(X_train))
print(len(y_train))
print(len(X_test))
print(len(y_test))
# Out:
# 368
# 368
# 246
# 246

# %%
# create logistic regression object 
clf = LogisticRegression()

# %%
# train the model using the training sets 
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# making predictions on the testing set 
## Testing Accuracy
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
clf = KNeighborsClassifier(n_neighbors= 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-cb53a74c3b5d> in <module>
#       1 from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
# ----> 2 clf = KNeighborsClassifier(n_neighbors= 3)
#
# NameError: name 'KNeighborsClassifier' is not defined

# %%
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
print('Accuracy_score: ',accuracy_score(y_test, y_pred)*100)
print('\n','Classification_report: ','\n','\n',classification_report(y_test, y_pred))
# Out:
# Accuracy_score:  82.11382113821138
#
#  Classification_report:
#
#                precision    recall  f1-score   support
#
#            N       0.97      0.48      0.64        82
#            Y       0.79      0.99      0.88       164
#
#     accuracy                           0.82       246
#    macro avg       0.88      0.73      0.76       246
# weighted avg       0.85      0.82      0.80       246

# %%
## Training Accuracy
y_train_pred = clf.predict(X_train)

# %%
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix

# %%
print('Accuracy_score: ',accuracy_score(y_train, y_train_pred)*100)
print('\n','Classification_report: ','\n','\n',classification_report(y_test, y_pred))
# Out:
# Accuracy_score:  81.25
#
#  Classification_report:
#
#                precision    recall  f1-score   support
#
#            N       0.97      0.48      0.64        82
#            Y       0.79      0.99      0.88       164
#
#     accuracy                           0.82       246
#    macro avg       0.88      0.73      0.76       246
# weighted avg       0.85      0.82      0.80       246

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 39  43]
#  [  1 163]]

# %%
### TESTING DATA ###

# %%
a=clf.predict(X_test)

# %%
a
# Out:
# array(['Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y',
#        'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
# ...

# %%
## SVC ###

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[  0  82]
#  [  0 164]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            N       0.00      0.00      0.00        82
#            Y       0.67      1.00      0.80       164
#
#     accuracy                           0.67       246
#    macro avg       0.33      0.50      0.40       246
# weighted avg       0.44      0.67      0.53       246

# %%
### GRID SEARCH ###

# %%
### any value from 0 to 1 ###
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=5)

# %%
# May take awhile!
grid.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.699, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.699, total=   0.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.705, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.699, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.699, total=   0.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.705, total=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
grid.best_estimator_
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
grid_predictions = grid.predict(X_test)

# %%
print(confusion_matrix(y_test,grid_predictions))
# Out:
# [[  2  80]
#  [  6 158]]

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            N       0.25      0.02      0.04        82
#            Y       0.66      0.96      0.79       164
#
#     accuracy                           0.65       246
#    macro avg       0.46      0.49      0.42       246
# weighted avg       0.53      0.65      0.54       246
